# %%
import wbdata
import pandas as pd
import requests
from datetime import datetime
# Retrieve indicators
result = wbdata.get_indicators()

# Convert the result to a DataFrame
df = pd.DataFrame(result)

# Display the first few rows of the DataFrame
print(df.head())

# Filter indicators related to debt
gender_indicators = df[df['name'].str.contains('gender', case=False, na=False)]

# Save the DataFrame to a CSV file
gender_indicators.to_csv('gender_indicators.csv', index=False)

print("CSV file 'gender_indicators.csv' has been created.")
# Out:
#                      id                                     name unit  \
# 0    1.0.HCount.1.90usd          Poverty Headcount ($1.90 a day)
# 1     1.0.HCount.2.5usd          Poverty Headcount ($2.50 a day)
# 2  1.0.HCount.Mid10to50    Middle Class ($10-50 a day) Headcount
# 3       1.0.HCount.Ofcl  Official Moderate Poverty Rate-National
# 4   1.0.HCount.Poor4uds             Poverty Headcount ($4 a day)
#
#                                     source  \
# 0  {'id': '37', 'value': 'LAC Equity Lab'}
# 1  {'id': '37', 'value': 'LAC Equity Lab'}
# 2  {'id': '37', 'value': 'LAC Equity Lab'}
# 3  {'id': '37', 'value': 'LAC Equity Lab'}
# 4  {'id': '37', 'value': 'LAC Equity Lab'}
#
#                                           sourceNote  \
# 0  The poverty headcount index measures the propo...
# 1  The poverty headcount index measures the propo...
# 2  The poverty headcount index measures the propo...
# 3  The poverty headcount index measures the propo...
# 4  The poverty headcount index measures the propo...
#
#                                   sourceOrganization  \
# 0  LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 1  LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 2  LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 3  LAC Equity Lab tabulations of data from Nation...
# 4  LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
#
#                                 topics
# 0  [{'id': '11', 'value': 'Poverty '}]
# 1  [{'id': '11', 'value': 'Poverty '}]
# 2  [{'id': '11', 'value': 'Poverty '}]
# 3  [{'id': '11', 'value': 'Poverty '}]
# 4  [{'id': '11', 'value': 'Poverty '}]
# CSV file 'gender_indicators.csv' has been created.

# %%
gender_indicators_df = pd.read_csv('gender_indicators.csv')

# Inspect the DataFrame to understand its structure
print(gender_indicators_df.head())
# Out:
#                      id                                               name  \
# 0           2.3_GIR.GPI  Gender parity index for gross intake ratio in ...
# 1           2.6_PCR.GPI   Gender parity index for primary completion rate
# 2  BI.EMP.PWRK.PB.FE.ZS  Public sector employment, as a share of paid e...
# 3  BI.EMP.PWRK.PB.MA.ZS  Public sector employment, as a share of paid e...
# 4  BI.EMP.TOTL.PB.FE.ZS  Public sector employment, as a share of total ...
#
#    unit                                             source  \
# 0   NaN  {'id': '34', 'value': 'Global Partnership for ...
# 1   NaN  {'id': '34', 'value': 'Global Partnership for ...
# 2   NaN  {'id': '64', 'value': 'Worldwide Bureaucracy I...
# 3   NaN  {'id': '64', 'value': 'Worldwide Bureaucracy I...
# 4   NaN  {'id': '64', 'value': 'Worldwide Bureaucracy I...
#
#                                           sourceNote  \
# 0  Ratio of female to male values of gross intake...
# 1  Ratio of female to male values of Primary Comp...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   sourceOrganization topics
# 0  Data were collected from national and other pu...     []
# 1  Data were collected from national and other pu...     []
# 2                                                NaN     []
# 3                                                NaN     []
# 4                                                NaN     []

# %%
# Extract IDs from the DataFrame
indicator_ids = gender_indicators_df['id'].tolist()

# %%
gender_indicators_df = pd.read_csv('gender_indicators.csv')

def fetch_indicator_data(indicator_id):
    url = f"http://api.worldbank.org/v2/indicator/{indicator_id}?format=json&per_page=50000"
    response = requests.get(url)
    response.raise_for_status()
    data = response.json()
    # Print the first few entries to inspect the structure
    print(data)
    return data

def extract_annual_data(data, indicator_id):
    annual_data = {}
    if data and isinstance(data, list) and len(data) > 1:
        indicator_data = data[1]  # The actual data is usually in the second item
        for entry in indicator_data:
            # Check for available keys
            year = entry.get('date')
            amount = entry.get('value')
            if year and amount is not None:
                if year not in annual_data:
                    annual_data[year] = {}
                annual_data[year][indicator_id] = amount
    return annual_data

def organize_data(indicator_ids):
    all_data = {}
    
    for indicator_id in indicator_ids:
        try:
            data = fetch_indicator_data(indicator_id)
            annual_data = extract_annual_data(data, indicator_id)
            for year, values in annual_data.items():
                if year not in all_data:
                    all_data[year] = {}
                all_data[year][indicator_id] = values.get(indicator_id, None)
        except requests.HTTPError as e:
            print(f"Failed to fetch data for indicator ID {indicator_id}: {e}")
    
    # Convert to DataFrame
    df = pd.DataFrame.from_dict(all_data, orient='index').sort_index()
    df.reset_index(inplace=True)
    df.rename(columns={'index': 'Year'}, inplace=True)
    return df

# Extract indicator IDs
indicator_ids = gender_indicators_df['id'].tolist()

# Organize data
data_df = organize_data(indicator_ids)
# Out:
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': '2.3_GIR.GPI', 'name': 'Gender parity index for gross intake ratio in grade 1', 'unit': '', 'source': {'id': '34', 'value': 'Global Partnership for Education'}, 'sourceNote': 'Ratio of female to male values of gross intake ratio for primary first grade. Country-specific definition, method and targets are determined by countries themselves. ', 'sourceOrganization': 'Data were collected from national and other publicly available sources, and validated by the Local Education Group (LEG) in each country. LEGs are typically led by the Ministry of Education and include development partners and other education stakeholders. Data were not processed or analyzed by the Global Partnership for Education. It is reported as it was presented in the original sources, or as it was communicated to us through the Coordinating Agency or Lead Donor of the LEG.', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': '2.6_PCR.GPI', 'name': 'Gender parity index for primary completion rate ', 'unit': '', 'source': {'id': '34', 'value': 'Global Partnership for Education'}, 'sourceNote': 'Ratio of female to male values of Primary Completion Rate. Country-specific definition, method and targets are determined by countries themselves. ', 'sourceOrganization': 'Data were collected from national and other publicly available sources, and validated by the Local Education Group (LEG) in each country. LEGs are typically led by the Ministry of Education and include development partners and other education stakeholders. Data were not processed or analyzed by the Global Partnership for Education. It is reported as it was presented in the original sources, or as it was communicated to us through the Coordinating Agency or Lead Donor of the LEG.', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.EMP.PWRK.PB.FE.ZS', 'name': 'Public sector employment, as a share of paid employment by gender: Female', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.EMP.PWRK.PB.MA.ZS', 'name': 'Public sector employment, as a share of paid employment by gender: Male', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.EMP.TOTL.PB.FE.ZS', 'name': 'Public sector employment, as a share of total employment by gender: Female', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.EMP.TOTL.PB.MA.ZS', 'name': 'Public sector employment, as a share of total employment by gender: Male', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FE', 'name': 'Public sector wage premium, by gender: Female (compared to all private employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# Failed to fetch data for indicator ID BI.WAG.PREM.PB.FM: 504 Server Error: Gateway Time-out for url: http://api.worldbank.org/v2/indicator/BI.WAG.PREM.PB.FM?format=json&per_page=50000
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.CA', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Core Public Administration (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.ED', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Education (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.HE', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Health (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.PA', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Public Administration (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.PS', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Public Safety (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.FM.SS', 'name': 'P-Value: Gender wage premium in the public sector, by industry: Social Security (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PB.MA', 'name': 'Public sector wage premium, by gender: Male (compared to all private employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PV.FM.ED', 'name': 'P-Value: Gender wage premium in the private sector, by industry: Education (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PV.FM.HE', 'name': 'P-Value: Gender wage premium in the private sector, by industry: Health (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PV.FM.MW', 'name': 'P-Value: Gender wage premium in the private sector, by occupation: Medical workers (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PREM.PV.FM.TS', 'name': 'P-Value: Gender wage premium in the private sector, by occupation: Teachers (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PRVS.ED.FM', 'name': 'Gender wage premium in the private sector, by industry: Education (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PRVS.HE.FM', 'name': 'Gender wage premium in the private sector, by industry: Health (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PRVS.MW.FM', 'name': 'Gender wage premium in the private sector, by occupation: Medical workers (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PRVS.TS.FM', 'name': 'Gender wage premium in the private sector, by occupation: Teachers (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.CA.FM', 'name': 'Gender wage premium in the public sector, by industry: Core Public Administration (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.ED.FM', 'name': 'Gender wage premium in the public sector, by industry: Education (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.HE.FM', 'name': 'Gender wage premium in the public sector, by industry: Health (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.PA.FM', 'name': 'Gender wage premium in the public sector, by industry: Public Administration (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.PS.FM', 'name': 'Gender wage premium in the public sector, by industry: Public Safety (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'BI.WAG.PUBS.SS.FM', 'name': 'Gender wage premium in the public sector, by industry: Social Security (compared to male paid employees)', 'unit': '', 'source': {'id': '64', 'value': 'Worldwide Bureaucracy Indicators'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.AGFE', 'name': 'Employment by sector and gender (% of total) - Agriculture - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Agriculture is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.AGMA', 'name': 'Employment by sector and gender (% of total) - Agriculture - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Agriculture is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.CMFE', 'name': 'Employment by sector and gender (% of total) - Commerce - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Commerce is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.CMMA', 'name': 'Employment by sector and gender (% of total) - Commerce - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Commerce is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.CNFE', 'name': 'Employment by sector and gender (% of total) - Construction - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Construction is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.CNMA', 'name': 'Employment by sector and gender (% of total) - Construction - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Construction is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.EUFE', 'name': 'Employment by sector and gender (% of total) - Electricity and utilities - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Electricity and Utilities is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.EUMA', 'name': 'Employment by sector and gender (% of total) - Electricity and utilities - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Electricity and Utilities is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.FBFE', 'name': 'Employment by sector and gender (% of total) - Financial and Business Services - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Financial and Business Services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.FBMA', 'name': 'Employment by sector and gender (% of total) - Financial and Business Services - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Financial and Business Services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.INFE', 'name': 'Employment by sector and gender (% of total) - Industry - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Industry is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.INMA', 'name': 'Employment by sector and gender (% of total) - Industry - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Industry is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.MAFE', 'name': 'Employment by sector and gender (% of total) - Manufacturing - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Manufacturing is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.MAMA', 'name': 'Employment by sector and gender (% of total) - Manufacturing - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Manufacturing is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.MIFE', 'name': 'Employment by sector and gender (% of total) - Mining - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Mining is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.MIMA', 'name': 'Employment by sector and gender (% of total) - Mining - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Mining is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.OSFE', 'name': 'Employment by sector and gender (% of total) - Other services - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Other services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.OSMA', 'name': 'Employment by sector and gender (% of total) - Other services - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Other services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.PAFE', 'name': 'Employment by sector and gender (% of total) - Public Administration - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Public Administration is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.PAMA', 'name': 'Employment by sector and gender (% of total) - Public Administration - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Public Administration is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.PSFE', 'name': 'Employment by sector and gender (% of total) - Public sector employment - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Public sector employment is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.PSMA', 'name': 'Employment by sector and gender (% of total) - Public sector employment - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Public sector employment is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.SEFE', 'name': 'Employment by sector and gender (% of total) - Services - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.SEMA', 'name': 'Employment by sector and gender (% of total) - Services - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Services is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.TCFE', 'name': 'Employment by sector and gender (% of total) - Transport & Communication - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Females within Transport & Communication is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ESG.TCMA', 'name': 'Employment by sector and gender (% of total) - Transport & Communication - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'Employment of Males within Transport & Communication is disaggregated from the Global Jobs Indicators Database. The Database covers socio-demographics, labor force status and employment type, employment composition by sector and occupation, education level completed, hours worked, and earnings. The database was compiled from national surveys and subnational microdata which was first harmonized for the Bank-wide I2D2 database, then quality checked by the Jobs Group.', 'sourceOrganization': 'Global Jobs Indicators Database, The World Bank. Available at: https://databank.worldbank.org/source/global-jobs-indicators-database-(join)', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.FFFE', 'name': 'Informal employment by sector and gender (% of total) - Agriculture, forestry and fishing - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of agriculture (female) employment which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.FFMA', 'name': 'Informal employment by sector and gender (% of total) - Agriculture, forestry and fishing - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of agriculture (male) employment which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.NAFE', 'name': 'Informal employment by sector and gender (% of total) - Non-agriculture - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of non-agriculture (female) employment which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.NAMA', 'name': 'Informal employment by sector and gender (% of total) - Non-agriculture - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of non-agriculture (male) employment which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.NBFE', 'name': 'Informal employment by sector and gender (% of total) - No breakdown - Female', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of employment that had no-breakdown as either non-agricultural or agricultural (female), which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'CC.ISG.NBMA', 'name': 'Informal employment by sector and gender (% of total) - No breakdown - Male', 'unit': '', 'source': {'id': '87', 'value': 'Country Climate and Development Report (CCDR)'}, 'sourceNote': 'This indicator presents the share of employment that had no-breakdown as either non-agricultural or agricultural (male), which is classified as informal employment in the total economy. Data is taken from the United Nations Sustainable Goals, representing Indicator 8.3.1: Proportion of informal employment in total employment, by sector and sex.', 'sourceOrganization': 'UN Open Data Hub. Available at: https://unstats-undesa.opendata.arcgis.com/', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'FB.FCP.BREG.PR.DI.SC', 'name': '589_Do laws and regulations prohibit or restrict discriminating consumers based on gender, ethnicity, faith, political affiliation, or appearance?  _#VHGA_03', 'unit': '', 'source': {'id': '69', 'value': 'Global Financial Inclusion and Consumer Protection Survey'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-1', 'name': 'Gender impact analysis of budget policy proposals', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-1.1', 'name': '(i) Gender impact analysis of expenditure policy proposals', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-1.2', 'name': 'Gender impact analysis of revenue policy proposals', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-2', 'name': 'Gender responsive public investment management', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-2.1', 'name': '(i) Gender responsive public investment management', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-3', 'name': 'Gender responsive budget circular', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-3.1', 'name': '(i) Gender responsive budget circular', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-4', 'name': 'Gender responsive budget proposal documentation', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-4.1', 'name': '(i) Gender responsive budget proposal documentation', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-6', 'name': 'Tracking budget expenditure for gender equality', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-6.1', 'name': '(i) Tracking budget expenditure for gender equality', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-7', 'name': 'Gender responsive reporting', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-7.1', 'name': '(i) Gender responsive reporting', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-8', 'name': 'Evaluation of gender impacts of service delivery', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-8.1', 'name': '(i) Evaluation of gender impacts of service delivery', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-9', 'name': 'Legislative scrutiny of gender impacts of the budget', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-9.1', 'name': '(i) Gender responsive legislative scrutiny of budgets', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'GRPFM-9.2', 'name': '(ii) Gender responsive legislative scrutiny of audit reports', 'unit': '', 'source': {'id': '79', 'value': 'PEFA_GRPFM'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'IQ.CPA.GNDR.XQ', 'name': 'CPIA gender equality rating (1=low to 6=high)', 'unit': '', 'source': {'id': '2', 'value': 'World Development Indicators'}, 'sourceNote': 'Gender equality assesses the extent to which the country has installed institutions and programs to enforce laws and policies that promote equal access for men and women in education, health, the economy, and protection under law.', 'sourceOrganization': 'World Bank Group, CPIA database (http://www.worldbank.org/ida).', 'topics': [{'id': '13', 'value': 'Public Sector '}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR', 'name': 'Female to male gender wage gap, aged 15-64, total', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR.HE', 'name': 'Female to male gender wage gap, aged 15-64, above primary education', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR.LE', 'name': 'Female to male gender wage gap, aged 15-64, primary education and below', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR.OL', 'name': 'Female to male gender wage gap, aged 25-64', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR.RU', 'name': 'Female to male gender wage gap, aged 15-64, rural', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'JI.WAG.GNDR.UR', 'name': 'Female to male gender wage gap, aged 15-64, urban', 'unit': '', 'source': {'id': '86', 'value': 'Global Jobs Indicators Database (JOIN)'}, 'sourceNote': '', 'sourceOrganization': '', 'topics': [{}]}]]
# Failed to fetch data for indicator ID JI.WAG.GNDR.YG: 504 Server Error: Gateway Time-out for url: http://api.worldbank.org/v2/indicator/JI.WAG.GNDR.YG?format=json&per_page=50000
# ...
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.SLE.4.GPI', 'name': 'School life expectancy, post-secondary non-tertiary, gender parity index (GPI)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'Ratio of female school life expectancy to the male school life expectancy. It is calculated by dividing the female value for the indicator by the male value for the indicator. A GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females.', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.SLE.56.GPI', 'name': 'School life expectancy, tertiary, gender parity index (GPI)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'Ratio of female school life expectancy to the male school life expectancy. It is calculated by dividing the female value for the indicator by the male value for the indicator. A GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females.', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{'id': '4', 'value': 'Education '}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.SR.1.G4.GPI', 'name': 'Survival rate to Grade 4 of primary education, gender parity index (GPI)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'Ratio of female survival rate to grade 4 to the male survival rate to grade 4. It is calculated by dividing the female value for the indicator by the male value for the indicator. A GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females.', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{'id': '4', 'value': 'Education '}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.SR.1.G5.GPI', 'name': 'Survival rate to Grade 5 of primary education, gender parity index (GPI)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'Ratio of female survival rate to grade 5 to the male survival rate to grade 5. It is calculated by dividing the female value for the indicator by the male value for the indicator. A GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females.', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{'id': '4', 'value': 'Education '}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.SR.1.GLAST.GPI', 'name': 'Survival rate to the last grade of primary education, gender parity index (GPI)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'Ratio of female survival rate to the last grade of primary education to the male survival rate to the last grade of primary education. It is calculated by dividing the female value for the indicator by the male value for the indicator. A GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females.', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{'id': '4', 'value': 'Education '}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TATTRR.02.GPIA', 'name': 'Teacher attrition rate from pre-primary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TATTRR.1.GPIA', 'name': 'Teacher attrition rate from primary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TATTRR.2.GPIA', 'name': 'Teacher attrition rate from lower secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TATTRR.2T3.GPIA', 'name': 'Teacher attrition rate from secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TATTRR.3.GPIA', 'name': 'Teacher attrition rate from upper secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TRTP.02.GPIA', 'name': 'Proportion of teachers with the minimum required qualifications in pre-primary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TRTP.1.GPIA', 'name': 'Proportion of teachers with the minimum required qualifications in primary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TRTP.2.GPIA', 'name': 'Proportion of teachers with the minimum required qualifications in lower secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TRTP.2T3.GPIA', 'name': 'Proportion of teachers with the minimum required qualifications in secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.TRTP.3.GPIA', 'name': 'Proportion of teachers with the minimum required qualifications in upper secondary education, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.YADULT.PROFILITERACY.GPIA', 'name': 'Proportion of population achieving at least a fixed level of proficiency in functional literacy skills, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]
# [{'page': 1, 'pages': 1, 'per_page': '50000', 'total': 1}, [{'id': 'UIS.YADULT.PROFINUMERACY.GPIA', 'name': 'Proportion of population achieving at least a fixed level of proficiency in functional numeracy skills, adjusted gender parity index (GPIA)', 'unit': '', 'source': {'id': '12', 'value': 'Education Statistics'}, 'sourceNote': 'The Adjusted Gender Parity Index (GPIA) is calculated by dividing the female value for the indicator by the male value for the indicator. If the resulting value exceeds 1, the ratio is inverted and subtracted from 2. The adjusted gender parity index is symmetrical around 1 and lies in the range 0-2. An adjusted GPI equal to 1 indicates parity between females and males. In general, a value less than 1 indicates disparity in favor of males and a value greater than 1 indicates disparity in favor of females. For more information, consult the UNESCO Institute for Statistics: http://uis.unesco.org/', 'sourceOrganization': 'UNESCO Institute for Statistics', 'topics': [{}]}]]

# %%
data_df.head()
# Out:
# Empty DataFrame
# Columns: [Year]
# Index: []
