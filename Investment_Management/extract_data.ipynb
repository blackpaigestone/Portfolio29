# %%
import os
import requests
import pandas as pd

# %%
def check_zip_signature(file_path):
    with open(file_path, 'rb') as f:
        header = f.read(4)
        return header == b'PK\x03\x04'

zip_path = "/Users/paigeblackstone/Desktop/2021FD.zip"
if check_zip_signature(zip_path):
    print("Valid ZIP file signature.")
else:
    print("Invalid ZIP file signature.")
# Out:
# Valid ZIP file signature.

# %%
response = requests.get(zip_url, stream=True)
print("Content-Type:", response.headers.get('Content-Type'))
# Out:
# Content-Type: application/x-zip-compressed

# %%
def download_zip(url, save_path):
    try:
        response = requests.get(url, stream=True)
        print(f"Content-Type: {response.headers.get('Content-Type')}")
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded ZIP file to {save_path}")
        else:
            print(f"Failed to download ZIP file. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading ZIP file: {e}")

# %%
def download_zip(url, save_path):
    try:
        print(f"Downloading from {url}")
        response = requests.get(url, stream=True)
        print(f"Response Status Code: {response.status_code}")
        print(f"Response Content-Type: {response.headers.get('Content-Type')}")
        if response.status_code == 200:
            with open(save_path, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded ZIP file to {save_path}")
        else:
            print(f"Failed to download ZIP file. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading ZIP file: {e}")

def check_zip_signature(file_path):
    try:
        with open(file_path, 'rb') as f:
            header = f.read(4)
            print(f"File header: {header}")
            return header == b'PK\x03\x04'
    except Exception as e:
        print(f"Error checking ZIP file signature: {e}")
        return False

# Example usage
years_list = ['2021', '2022', '2023', '2024']
base_url = "https://disclosures-clerk.house.gov/public_disc/financial-pdfs/{year}FD.zip"
desktop_dir = os.path.expanduser("~/Desktop")

for year in years_list:
    zip_url = base_url.format(year=year)
    zip_filename = f"{year}FD.zip"
    zip_path = os.path.join(desktop_dir, zip_filename)
    
    # Download the ZIP file
    download_zip(zip_url, zip_path)
    
    # Verify ZIP file signature
    if check_zip_signature(zip_path):
        print(f"{zip_path} is a valid ZIP file.")
    else:
        print(f"{zip_path} is not a valid ZIP file or is corrupted.")
# Out:
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2021FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2021FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2021FD.zip is a valid ZIP file.
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2022FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2022FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2022FD.zip is a valid ZIP file.
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2023FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2023FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2023FD.zip is a valid ZIP file.
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2024FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2024FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2024FD.zip is a valid ZIP file.

# %%
def extract_zip(zip_path, extract_dir):
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_dir)
        print(f"Extracted contents to {extract_dir}")
    except zipfile.BadZipFile:
        print(f"Bad ZIP file: {zip_path}")
    except Exception as e:
        print(f"Error extracting ZIP file: {e}")

def read_files_from_directory(directory_path):
    data_frames = {}
    for file_name in os.listdir(directory_path):
        file_path = os.path.join(directory_path, file_name)
        if file_name.endswith('.txt'):
            # Read text file into DataFrame, adjust delimiter if needed
            df = pd.read_csv(file_path, delimiter='\t')  # Assuming tab-delimited
            data_frames[file_name] = df
        elif file_name.endswith('.xml'):
            # Read XML file into DataFrame
            df = pd.read_xml(file_path)
            data_frames[file_name] = df
    return data_frames

# %%
years_list = ['2021', '2022', '2023', '2024']
base_url = "https://disclosures-clerk.house.gov/public_disc/financial-pdfs/{year}FD.zip"
desktop_dir = os.path.expanduser("~/Desktop")

for year in years_list:
    zip_url = base_url.format(year=year)
    zip_filename = f"{year}FD.zip"
    zip_path = os.path.join(desktop_dir, zip_filename)
    extracted_dir = os.path.join(desktop_dir, year)
    
    # Download the ZIP file
    download_zip(zip_url, zip_path)
    
    # Verify ZIP file signature
    if check_zip_signature(zip_path):
        print(f"{zip_path} is a valid ZIP file.")
        
        # Extract the ZIP file
        extract_zip(zip_path, extracted_dir)
        
        # Read extracted files into DataFrames
        data_frames = read_files_from_directory(extracted_dir)
        
        # Print the DataFrames or do further processing
        for file_name, df in data_frames.items():
            print(f"Data from {file_name}:")
            print(df.head())
# Out:
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2021FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2021FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2021FD.zip is a valid ZIP file.
# Extracted contents to /Users/paigeblackstone/Desktop/2021
# Data from 2021FD.xml:
#   Prefix        Last           First Suffix FilingType StateDst  Year  \
# 0   None      Aazami         Shervin   None          C     CA30  2021
# 1   None  Abdelhamid            Rana   None          C     NY12  2021
# 2   None   Achenbach     Jack Joseph   None          A     FL10  2021
# 3   None   Achenbach     Jack Joseph   None          C     FL10  2021
# 4   None     Acheson  Phelan Douglas   None          W     UT02  2021
#
#   FilingDate     DocID
# 0  2/22/2021  10039551
# 1  5/14/2021  10039753
# 2   7/8/2021  10041290
# 3   7/7/2021  10041275
# 4       None   8218052
# Data from 2021FD.txt:
#   Prefix        Last           First Suffix FilingType StateDst  Year  \
# 0    NaN      Aazami         Shervin    NaN          C     CA30  2021
# 1    NaN  Abdelhamid            Rana    NaN          C     NY12  2021
# 2    NaN   Achenbach     Jack Joseph    NaN          A     FL10  2021
# 3    NaN   Achenbach     Jack Joseph    NaN          C     FL10  2021
# 4    NaN     Acheson  Phelan Douglas    NaN          W     UT02  2021
#
#   FilingDate     DocID
# 0  2/22/2021  10039551
# 1  5/14/2021  10039753
# 2   7/8/2021  10041290
# 3   7/7/2021  10041275
# 4        NaN   8218052
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2022FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2022FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2022FD.zip is a valid ZIP file.
# Extracted contents to /Users/paigeblackstone/Desktop/2022
# Data from 2022FD.txt:
#   Prefix              Last                           First Suffix FilingType  \
# 0    Mr.           Hollier  Adam Jacques Chester Lafayette    NaN          C
# 1    NaN           Aadland                            Erik    NaN          C
# 2    NaN  Acevedo-Arreguin                    Luis Antonio    NaN          C
# 3    NaN         Achenbach                     Jack Joseph    NaN          C
# 4   Hon.             Adams                    Alma Shealey    NaN          O
#
#   StateDst  Year FilingDate     DocID
# 0     MI13  2022  5/14/2022  10048102
# 1     CO07  2022  1/17/2022  10044401
# 2     CA18  2022  4/23/2022  10046717
# 3     FL10  2022  5/15/2022  10048864
# 4     NC12  2022  5/10/2023  10053784
# Data from 2022FD.xml:
#   Prefix              Last                           First Suffix FilingType  \
# 0    Mr.           Hollier  Adam Jacques Chester Lafayette   None          C
# 1   None           Aadland                            Erik   None          C
# 2   None  Acevedo-Arreguin                    Luis Antonio   None          C
# 3   None         Achenbach                     Jack Joseph   None          C
# 4   Hon.             Adams                    Alma Shealey   None          O
#
#   StateDst  Year FilingDate     DocID
# 0     MI13  2022  5/14/2022  10048102
# 1     CO07  2022  1/17/2022  10044401
# 2     CA18  2022  4/23/2022  10046717
# 3     FL10  2022  5/15/2022  10048864
# 4     NC12  2022  5/10/2023  10053784
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2023FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2023FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2023FD.zip is a valid ZIP file.
# Extracted contents to /Users/paigeblackstone/Desktop/2023
# Data from 2023FD.xml:
#   Prefix     Last                           First Suffix FilingType StateDst  \
# 0   None  Hollier  Adam Jacques Chester Lafayette   None          C     MI13
# 1   None    Aasen                       Andrew J.   None          C     OR05
# 2   None     Abel                         William   None          C     TX31
# 3   None     Abel                         William   None          D     TX31
# 4   None     Abid                           Zerqa   None          C     OH15
#
#    Year  FilingDate     DocID
# 0  2023   2/14/2024  10056211
# 1  2023    8/5/2023  10055494
# 2  2023  12/18/2023  10056442
# 3  2023   5/15/2023  40003491
# 4  2023   1/11/2024  10056168
# Data from 2023FD.txt:
#   Prefix     Last                           First Suffix FilingType StateDst  \
# 0    NaN  Hollier  Adam Jacques Chester Lafayette    NaN          C     MI13
# 1    NaN    Aasen                       Andrew J.    NaN          C     OR05
# 2    NaN     Abel                         William    NaN          C     TX31
# 3    NaN     Abel                         William    NaN          D     TX31
# 4    NaN     Abid                           Zerqa    NaN          C     OH15
#
#    Year  FilingDate     DocID
# 0  2023   2/14/2024  10056211
# 1  2023    8/5/2023  10055494
# 2  2023  12/18/2023  10056442
# 3  2023   5/15/2023  40003491
# 4  2023   1/11/2024  10056168
# Downloading from https://disclosures-clerk.house.gov/public_disc/financial-pdfs/2024FD.zip
# Response Status Code: 200
# Response Content-Type: application/x-zip-compressed
# Downloaded ZIP file to /Users/paigeblackstone/Desktop/2024FD.zip
# File header: b'PK\x03\x04'
# /Users/paigeblackstone/Desktop/2024FD.zip is a valid ZIP file.
# Extracted contents to /Users/paigeblackstone/Desktop/2024
# Data from 2024FD.txt:
#   Prefix        Last      First Suffix FilingType StateDst  Year FilingDate  \
# 0    NaN        Abel    William    NaN          C     TX31  2024  5/12/2024
# 1    NaN   Abolfazli    Maryam.    NaN          C     TN05  2024  5/13/2024
# 2    Mr.  Aboujaoude  Rock Adel    Jr.          C     FL12  2024  5/14/2024
# 3    NaN       Adams   Jennifer    NaN          C     FL07  2024  5/30/2024
# 4    NaN       Adams  Sheryl L.    NaN          W     CA49  2024  4/22/2024
#
#       DocID
# 0  10060658
# 1  10060479
# 2  10061019
# 3  10062032
# 4      7940
# Data from 2024FD.xml:
#   Prefix        Last      First Suffix FilingType StateDst  Year FilingDate  \
# 0   None        Abel    William   None          C     TX31  2024  5/12/2024
# 1   None   Abolfazli    Maryam.   None          C     TN05  2024  5/13/2024
# 2    Mr.  Aboujaoude  Rock Adel    Jr.          C     FL12  2024  5/14/2024
# 3   None       Adams   Jennifer   None          C     FL07  2024  5/30/2024
# 4   None       Adams  Sheryl L.   None          W     CA49  2024  4/22/2024
#
#       DocID
# 0  10060658
# 1  10060479
# 2  10061019
# 3  10062032
# 4      7940

# %%
df.columns.to_list()
# Out:
# ['Prefix',
#  'Last',
#  'First',
#  'Suffix',
#  'FilingType',
#  'StateDst',
#  'Year',
#  'FilingDate',
#  'DocID']
